# %% [markdown]
# ## *a01
#
# **計算**並**輸出**以下數學式的結果 :
#
# $5 \times (854193^4 + 1291) - 37871 \times [2^{64} + 5^{28} - 2^3 \times 3^3 \times 13 \times 23 \times (187086 \times 10^9 + 799242293)]$

# %%
# write your code here

# %% [markdown]
# ## *a04
#
# python中內建的`math`函式庫記錄著圓周率 $\pi$ 的約略值，我們從函式庫內匯入之後就能使用此數值，如下面的範例所示。
#
# 請將下方範例程式中的第四行 :
#
# ```python
# print("PI = %f" %(pi))
# ```
#
# 改寫，使結果輸出到小數點後的60位

# %%
# pi 使用範例
from math import pi

print("PI = %f" %(pi))

# %% [markdown]
# ## *a05
#
# 使用者輸入兩個數`a`與`b`，計算`a` `b`之間所有數(包含`a`跟`b`)平方值的和
#
# * **輸入說明**
#
# > 輸入共有兩行，每一行有一個整數，分別為`a`與`b`的值(`a` 恆小於 `b`)
#
# * **輸出說明**
#
# > `a` `b`之間所有數(包含`a`跟`b`)平方值的和
#
# * **example 1**
#
#     * 輸入
#
#     > `3`
#     > `5`
#
#     * 輸出
#
#     > `50`
#
#     * Explanation
#
#     $3^2 + 4^2 + 5^2 = 9 + 16 + 25 = 50$
#
# * **example 2**
#
#     * 輸入
#
#     > `7`
#     > `12`
#
#     * 輸出
#
#     > `559`
#
#     * Explanation
#
#     $7^2 + 8^2 + 9^2 + 10^2 + 11^2 + 12^2 = 49 + 64 + 81 + 100 + 121 + 144 = 559$

# %%
a = int(input())
b = int(input())
# write your code from here
# Out:
#  13

# %% [markdown]
# ## *b02
#
# 小明在寫code的時候有點卡關，請幫他修正下面的程式碼，讓程式會輸出以下的結果 :
#
# > ```
# > *
# > **
# > ***
# > ****
# > *****
# > ```

# %%
for i in range(5):
    for j in range(i):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# ## *b04
#
# 現在有份文件`names.txt`紀錄一些學生及他的學號，姓名與學號之間用空白隔開，如下 :
#
# ```
# 411071112 陳仰玟
# 411071114 陸新玫
# 411071115 陳晏樺
# 411071116 鄧蘭茂
# 411071118 賴怡潔
# 411071120 朱京念
# 411071122 李苑旭
# 411071124 李政宏
# 411071125 林承翰
# 411071126 許亦禮
# ```
#
# 請自行建立這個檔案，再使用 python 程式將這個檔案的內容讀取出來，並依照內容產生一個`dict`容器(名字自訂)。
# 其中`key`為該名學生的學號(不一定要轉型成數字型態)，`value`為該名學生的姓名，這個`dict`容器會長得像這樣 :
#
# ```python
# {'411071112': '陳仰玟',
#  '411071114': '陸新玫',
#  '411071115': '陳晏樺',
#  '411071116': '鄧蘭茂',
#  '411071118': '賴怡潔',
#  '411071120': '朱京念',
#  '411071122': '李苑旭',
#  '411071124': '李政宏',
#  '411071125': '林承翰',
#  '411071126': '許亦禮'}
# ```

# %%
# write your code here

# %% [markdown]
# ## *c02
#
# ![img](data:image/png;base64,...)
#
# 以上的`Scratch`程式會將**1 ~ 100**內的所有質數"說"出來(在`Scratch`裡面是用說的沒錯)。現在請你改用`python`的語法，使用與上面的`Scratch`程式相似的方式，找出**1 ~ 1000**內的所有質數，並將他們輸出。
#
# * **當旗子被點擊** : 在python程式內可省略
# * **說出`number`** : 改用`print(number)`
# * **等待`0.1`秒** : python程式內可省略
#
# 請把程式碼寫在下方的程式碼區塊中。

# %%
# write your code here

# %% [markdown]
# ## *d01
#
# 已知費式數列的定義如下 :
#
# * $F_0 = 0$
# * $F_1 = 1$
# * $F_n = F_{n-1} + F_{n-2}, for \space n \geq 2 \space and \space n \in Z^+$
#
# 簡而言之，數列的第0項為0，第1項為1，第二項開始則為該項的前兩項和，如第二項為第零項及第一項之和。
#
# 我們可以使用遞迴的方式來計算費式數列中每一項的值，例如以下的 python 程式 :
#
# ```python
# def fib(n):
#     if n == 0 :
#         return 0
#     if n == 1:
#         return 1
#     else:
#         return fib(n-1) + fib(n-2)
# ```
#
# 現在請你設計一個函式`calculate_fib_recursion_times(n)`，`n`代表費式數列的第`n`項，請計算並回傳(`return`)若使用上方的遞迴程式共需要呼叫幾次`fib()`函式。**參數`n`介於0~1000之間。**
#
# 如 :
#
# * `calculate_fib_recursion_times(3)` = 5，因為執行`fib(3)`時共需要呼叫 5 次`fib()`函式(如下圖)
#
# <img src="https://i.imgur.com/tMUpMTa.jpg" width="400" />
#
# * `calculate_fib_recursion_times(5)` = 15
#
# <img src="https://i.imgur.com/J6JdGyp.jpg" width="600" />

# %%
# function calculate_fib_recursion_times()
def calculate_fib_recursion_times(n):
    # write your code from here
    
    return
