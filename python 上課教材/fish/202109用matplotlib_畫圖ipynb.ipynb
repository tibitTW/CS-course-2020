# %% [markdown]
# # TextBook Chapter07 matplot資訊圖表繪製
#
# Matplotlib參考網站
# https://blog.techbridge.cc/2018/05/11/python-data-science-and-machine-learning-matplotlib-tutorial/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 5, 1)
x2 = np.arange(1, 5, .1)

y = np.cos(x)
y2 = np.cos(x2)

plt.plot(x, y, 'r')
plt.plot(x2, y2, 'g')

# %%
plt.plot(x, y, 'r')

# %%
x=[1,2,3,4,5,6,7,8,9]
y1=[1,3,5,1,3,5,1,3,5]

plt.plot(x, y1, '--m')

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5,6,7,8,9]
y1=[1,3,5,1,3,5,1,3,5]
y2=[2,4,6,4,6,2,6,4,2]
plt.plot(x,y1, label='apple')
plt.plot(x,y2, 'o-',label='orange')

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y1=[1,3,5,1,3,5,1,3,5]
y2=[2,4,6,4,6,2,6,4,2]
plt.plot(x,y1, label="apple")
plt.plot(x,y2, label="orange")

plt.plot()

plt.xlabel("year")
plt.ylabel("amount")
plt.title("Good Farm")
plt.legend
plt.show()

# %%
x = pd.period_range(pd.datetime.now(), periods=200, freq='d')
x = x.to_timestamp().to_pydatetime()
# 產生4組，每組 200 個隨機常態分布元素
y = np.random.randn(200, 4).cumsum(0)
plt.plot(x, y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.

# %%
# 設定標籤
plots = plt.plot(x, y)
plt.legend(plots, ('AAA', 'BBB', 'CCC'), loc='best', framealpha=0.5, prop={'size': 'large', 'family': 'monospace'})
plt.show()

# %%
# 標題與軸標籤
plt.title('Random Trends')
plt.xlabel('Date')
plt.ylabel('Cum. Sum')
plt.figtext(0.8, 0.01, 'ITE', ha='right', va='bottom')
# Out:
# Text(0.8, 0.01, 'ITE')

# %%
# 線圖
age = [4, 6, 10, 17, 18]
points = [15, 20, 22, 24, 20]

plt.plot(age, points)
plt.show()

# %%
 # 長條圖
 labels = ['Physics', 'Chemistry', 'Literature', 'Peace']
 foo_data = [3, 6, 10, 4]
 bar_width = 0.8
 xlocations = np.array(range(len(foo_data))) + bar_width

 plt.bar(xlocations, foo_data, width=bar_width)

 plt.title('Final Grade')
 plt.show()

# %%
# 圓餅圖
 data = np.random.randint(2, 100, 5) # 生成5筆資料
 x = np.arange(len(data))
 labels= 'A','B','C','D','E'
 plt.pie(data)
 plt.show()

# %%
 data = np.random.randint(2, 100, 5) # 生成5筆資料
 x = np.arange(len(data))
 labels= 'A','B','C','D','E'
 plt.pie(data , labels = labels,autopct='%1.1f%%')

 plt.show()
